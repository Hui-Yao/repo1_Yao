# %%
#导入包

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=7, micro=6, releaselevel='final', serial=0)
# matplotlib 3.1.3
# numpy 1.18.1
# pandas 1.0.1
# sklearn 0.22.1
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
# 加载数据集，输出数据集形状，并将训练集分出一部分为验证集
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all,y_train_all),(x_test,y_test) = fashion_mnist.load_data()
x_train,y_train = x_train_all[:55000],y_train_all[:55000]
x_valid,y_valid = x_train_all[55000:],y_train_all[55000:]

type(fashion_mnist)
for i in x_train_all,y_train_all,x_test,y_test:
    print(i.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
#对数据进行标准化
from sklearn.preprocessing import StandardScaler

fashion_mnist = keras.datasets.fashion_mnist
(x_tarin_all,y_train_all),(x_test,y_test) = fashion_mnist.load_data()
x_train,y_train = x_tarin_all[:55000],y_train_all[:55000]
x_valid,y_valid = x_tarin_all[55000:],y_train_all[55000:]

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(
                                        x_train.astype(np.float32).reshape(-1,1)
                                      ).reshape(-1,28,28) 
x_valid_scaled = scaler.transform(
                                    x_valid.astype(np.float32).reshape(-1,1)
                                  ).reshape(-1,28,28)
x_test_scaled = scaler.transform(
                                    x_test.astype(np.float32).reshape(-1,1)
                                ).reshape(-1,28,28)
                

# reshape中某个维度设为-1，意为先计算别的维度，最后由别的维度确定这个维度的数值。-1可以出现在任何一个维度上。



# standardscaler这个类只能接受二维数组，所以要将图片先转为二维数据

# StandardScaler.fit_transform():(1)使训练集均值为0，方差为1；并且记住调用该函数的几个的均值与方差，供后面的standardscaler.transform（）使用。
# StandardScaler.transform():使用fit_transform纪律的均值与方差，对当前数据集进行转换。

# 训练集调用fit_transform(),验证集与测试集调用transform()而不能调用fit_transform()，因为只有用训练集的均值与方差，擦能真实地反映训练结果。

# %%
#构建模型

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape = (28,28)))    #原始数据是图片，首先要展平成一位向量
model.add(keras.layers.Dense(units = 700,activation = 'relu'))
model.add(keras.layers.Dense(units = 300, activation = 'relu'))
model.add(keras.layers.Dense(units = 10, activation = 'softmax'))

model.compile(loss = 'sparse_categorical_crossentropy',     #如果标签是一个向量，那么就不要sparse，否则就加sparse
              optimizer = 'adam',
              metrics = ['accuracy'] )

history = model.fit(x_train_scaled,y_train,validation_data=(x_valid_scaled,y_valid),batch_size=200, epochs = 10)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 6s 104us/sample - loss: 0.4590 - accuracy: 0.8332 - val_loss: 0.3899 - val_accuracy: 0.8554
# Epoch 2/10
# 55000/55000 [==============================] - 5s 84us/sample - loss: 0.3341 - accuracy: 0.8770 - val_loss: 0.3569 - val_accuracy: 0.8716
# Epoch 3/10
# 55000/55000 [==============================] - 5s 84us/sample - loss: 0.2966 - accuracy: 0.8916 - val_loss: 0.3279 - val_accuracy: 0.8762
# Epoch 4/10
# 55000/55000 [==============================] - 4s 81us/sample - loss: 0.2713 - accuracy: 0.8986 - val_loss: 0.3266 - val_accuracy: 0.8796
# Epoch 5/10
# 55000/55000 [==============================] - 5s 82us/sample - loss: 0.2507 - accuracy: 0.9074 - val_loss: 0.3058 - val_accuracy: 0.8874
# Epoch 6/10
# 55000/55000 [==============================] - 4s 82us/sample - loss: 0.2319 - accuracy: 0.9133 - val_loss: 0.3285 - val_accuracy: 0.8822
# Epoch 7/10
# 55000/55000 [==============================] - 5s 86us/sample - loss: 0.2128 - accuracy: 0.9197 - val_loss: 0.3300 - val_accuracy: 0.8754
# Epoch 8/10
# 55000/55000 [==============================] - 5s 83us/sample - loss: 0.2056 - accuracy: 0.9226 - val_loss: 0.3107 - val_accuracy: 0.8884
# Epoch 9/10
# 55000/55000 [==============================] - 5s 83us/sample - loss: 0.1893 - accuracy: 0.9281 - val_loss: 0.3367 - val_accuracy: 0.8862
# Epoch 10/10
# 55000/55000 [==============================] - 5s 84us/sample - loss: 0.1838 - accuracy: 0.9307 - val_loss: 0.3548 - val_accuracy: 0.8824

# %%
model.evaluate(x_test_scaled,y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.3555949452280998, 0.8854]

# %%
print(history)
history.history
# Out:
# <tensorflow.python.keras.callbacks.History object at 0x000001DA83C18D08>
# {'loss': [0.46626016438007356,
#   0.33380383356051013,
#   0.29385032670064404,
#   0.2706107120351358,
#   0.248207753544504,
#   0.23084472667087208,
#   0.2178310234167359,
#   0.20277200533585116,
#   0.18705643304369665,
#   0.17992822070013392],
#  'accuracy': [0.8309818,
#   0.8748182,
#   0.8920182,
#   0.8994727,
#   0.9080909,
#   0.91316366,
#   0.91794544,
#   0.9234545,
#   0.9287091,
#   0.93192726],
#  'val_loss': [0.37835814476013185,
#   0.3277895879745483,
#   0.3300835525989532,
#   0.30828116357326507,
#   0.34653963208198546,
#   0.3114466792345047,
#   0.3118775075674057,
#   0.30516272485256196,
#   0.3202886772155762,
#   0.33913184463977813],
#  'val_accuracy': [0.8622,
#   0.8772,
#   0.8776,
#   0.8868,
#   0.875,
#   0.8856,
#   0.8876,
#   0.8946,
#   0.8914,
#   0.8886]}

# %%
#输出训练曲线图
def plot_show(history):
    data = pd.DataFrame(history.history)
    data.plot(figsize = (8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
plot_show(history)
